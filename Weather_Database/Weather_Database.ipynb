# %%
#Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import requests
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=272666654a3510eed84ebde20fd6cb2e

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=272666654a3510eed84ebde20fd6cb2e&q=Boston

# %%
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country":city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cidreira
# Processing Record 2 of Set 1 | saint george
# Processing Record 3 of Set 1 | kisangani
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | port hardy
# Processing Record 7 of Set 1 | victoria
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | nemuro
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | hithadhoo
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | esperance
# Processing Record 17 of Set 1 | saraland
# Processing Record 18 of Set 1 | ponta do sol
# Processing Record 19 of Set 1 | clyde river
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | tiksi
# Processing Record 22 of Set 1 | longyearbyen
# Processing Record 23 of Set 1 | talant
# Processing Record 24 of Set 1 | goba
# Processing Record 25 of Set 1 | cozumel
# Processing Record 26 of Set 1 | de-kastri
# Processing Record 27 of Set 1 | mar del plata
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | piacabucu
# Processing Record 31 of Set 1 | qaanaaq
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | ilulissat
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | yellowknife
# Processing Record 36 of Set 1 | hirara
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | grindavik
# Processing Record 40 of Set 1 | mount gambier
# Processing Record 41 of Set 1 | chuy
# Processing Record 42 of Set 1 | castro
# Processing Record 43 of Set 1 | corralillo
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | cherskiy
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | carnarvon
# Processing Record 48 of Set 1 | fairbanks
# Processing Record 49 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 1 | talnakh
# Processing Record 1 of Set 2 | carmen
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | beringovskiy
# Processing Record 4 of Set 2 | mayor pablo lagerenza
# Processing Record 5 of Set 2 | ushuaia
# Processing Record 6 of Set 2 | cabo san lucas
# Processing Record 7 of Set 2 | portland
# Processing Record 8 of Set 2 | puerto narino
# Processing Record 9 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 2 | lasem
# Processing Record 11 of Set 2 | santa maria
# Processing Record 12 of Set 2 | ribeira grande
# Processing Record 13 of Set 2 | tasiilaq
# Processing Record 14 of Set 2 | yar-sale
# Processing Record 15 of Set 2 | arkansas city
# Processing Record 16 of Set 2 | katsuura
# Processing Record 17 of Set 2 | bengkulu
# Processing Record 18 of Set 2 | samarai
# Processing Record 19 of Set 2 | baykit
# Processing Record 20 of Set 2 | sorong
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | hambantota
# Processing Record 23 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 2 | jamsa
# Processing Record 25 of Set 2 | kodiak
# Processing Record 26 of Set 2 | mogadishu
# Processing Record 27 of Set 2 | fort morgan
# Processing Record 28 of Set 2 | harper
# Processing Record 29 of Set 2 | izhma
# Processing Record 30 of Set 2 | lompoc
# Processing Record 31 of Set 2 | bethel
# Processing Record 32 of Set 2 | port elizabeth
# Processing Record 33 of Set 2 | sembe
# Processing Record 34 of Set 2 | bambous virieux
# Processing Record 35 of Set 2 | dicabisagan
# Processing Record 36 of Set 2 | lumphat
# Processing Record 37 of Set 2 | rawson
# Processing Record 38 of Set 2 | hami
# Processing Record 39 of Set 2 | vestmannaeyjar
# Processing Record 40 of Set 2 | ancud
# Processing Record 41 of Set 2 | arraial do cabo
# Processing Record 42 of Set 2 | adrar
# Processing Record 43 of Set 2 | laguna
# Processing Record 44 of Set 2 | la cruz
# Processing Record 45 of Set 2 | turmalina
# Processing Record 46 of Set 2 | fort saint john
# City not found. Skipping...
# Processing Record 47 of Set 2 | santa marta
# Processing Record 48 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 2 | thompson
# Processing Record 50 of Set 2 | anadyr
# Processing Record 1 of Set 3 | salalah
# Processing Record 2 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 3 | houma
# Processing Record 4 of Set 3 | lima
# Processing Record 5 of Set 3 | butaritari
# Processing Record 6 of Set 3 | zyryanskoye
# Processing Record 7 of Set 3 | parabel
# Processing Record 8 of Set 3 | sinnamary
# Processing Record 9 of Set 3 | yerbogachen
# Processing Record 10 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 3 | san andres
# Processing Record 12 of Set 3 | pemangkat
# Processing Record 13 of Set 3 | vaini
# Processing Record 14 of Set 3 | albany
# Processing Record 15 of Set 3 | mareeba
# Processing Record 16 of Set 3 | khasan
# Processing Record 17 of Set 3 | kenora
# Processing Record 18 of Set 3 | evensk
# Processing Record 19 of Set 3 | coffs harbour
# Processing Record 20 of Set 3 | afsin
# Processing Record 21 of Set 3 | port lincoln
# Processing Record 22 of Set 3 | grand gaube
# Processing Record 23 of Set 3 | rio tuba
# Processing Record 24 of Set 3 | faanui
# Processing Record 25 of Set 3 | novoorsk
# Processing Record 26 of Set 3 | mitsamiouli
# Processing Record 27 of Set 3 | greensboro
# Processing Record 28 of Set 3 | peterhead
# Processing Record 29 of Set 3 | avarua
# Processing Record 30 of Set 3 | sola
# Processing Record 31 of Set 3 | barcelos
# Processing Record 32 of Set 3 | upernavik
# Processing Record 33 of Set 3 | tuatapere
# Processing Record 34 of Set 3 | tuktoyaktuk
# Processing Record 35 of Set 3 | lardos
# Processing Record 36 of Set 3 | lata
# Processing Record 37 of Set 3 | lebu
# Processing Record 38 of Set 3 | san patricio
# Processing Record 39 of Set 3 | provideniya
# Processing Record 40 of Set 3 | gander
# Processing Record 41 of Set 3 | ahwa
# Processing Record 42 of Set 3 | deer lake
# Processing Record 43 of Set 3 | east london
# Processing Record 44 of Set 3 | mandalgovi
# Processing Record 45 of Set 3 | comodoro rivadavia
# Processing Record 46 of Set 3 | bagdarin
# Processing Record 47 of Set 3 | raudeberg
# Processing Record 48 of Set 3 | troitsko-pechorsk
# Processing Record 49 of Set 3 | ahipara
# Processing Record 50 of Set 3 | porto novo
# Processing Record 1 of Set 4 | ponta delgada
# Processing Record 2 of Set 4 | buala
# Processing Record 3 of Set 4 | new norfolk
# Processing Record 4 of Set 4 | acarau
# Processing Record 5 of Set 4 | pahrump
# Processing Record 6 of Set 4 | luderitz
# Processing Record 7 of Set 4 | nikolskoye
# Processing Record 8 of Set 4 | kaoma
# Processing Record 9 of Set 4 | springbok
# Processing Record 10 of Set 4 | te anau
# Processing Record 11 of Set 4 | namatanai
# Processing Record 12 of Set 4 | ures
# Processing Record 13 of Set 4 | the valley
# Processing Record 14 of Set 4 | la reforma
# Processing Record 15 of Set 4 | necochea
# Processing Record 16 of Set 4 | cayenne
# Processing Record 17 of Set 4 | saurimo
# Processing Record 18 of Set 4 | la ronge
# Processing Record 19 of Set 4 | petrovsk-zabaykalskiy
# Processing Record 20 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 4 | dobson
# Processing Record 22 of Set 4 | shakawe
# Processing Record 23 of Set 4 | norman wells
# Processing Record 24 of Set 4 | chadiza
# Processing Record 25 of Set 4 | klaksvik
# Processing Record 26 of Set 4 | kahului
# Processing Record 27 of Set 4 | riyadh
# Processing Record 28 of Set 4 | geraldton
# Processing Record 29 of Set 4 | sao joao da barra
# Processing Record 30 of Set 4 | barkhan
# Processing Record 31 of Set 4 | malanje
# Processing Record 32 of Set 4 | yulara
# Processing Record 33 of Set 4 | marawi
# Processing Record 34 of Set 4 | lensk
# Processing Record 35 of Set 4 | arlit
# Processing Record 36 of Set 4 | agadir
# Processing Record 37 of Set 4 | buta
# Processing Record 38 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 4 | visby
# Processing Record 40 of Set 4 | ciudad real
# Processing Record 41 of Set 4 | walvis bay
# Processing Record 42 of Set 4 | ambon
# Processing Record 43 of Set 4 | garoua
# Processing Record 44 of Set 4 | onega
# Processing Record 45 of Set 4 | paita
# Processing Record 46 of Set 4 | alyangula
# Processing Record 47 of Set 4 | lephepe
# City not found. Skipping...
# Processing Record 48 of Set 4 | palasa
# Processing Record 49 of Set 4 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 50 of Set 4 | numan
# Processing Record 1 of Set 5 | nzerekore
# Processing Record 2 of Set 5 | atar
# Processing Record 3 of Set 5 | onalaska
# Processing Record 4 of Set 5 | oranjemund
# Processing Record 5 of Set 5 | rio grande
# Processing Record 6 of Set 5 | maloy
# Processing Record 7 of Set 5 | tual
# Processing Record 8 of Set 5 | hilo
# Processing Record 9 of Set 5 | cobija
# Processing Record 10 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 5 | la fleche
# Processing Record 12 of Set 5 | nanortalik
# Processing Record 13 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 14 of Set 5 | shingu
# Processing Record 15 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 5 | tautira
# Processing Record 17 of Set 5 | mayumba
# Processing Record 18 of Set 5 | whitehorse
# Processing Record 19 of Set 5 | torbay
# Processing Record 20 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 21 of Set 5 | saint-philippe
# Processing Record 22 of Set 5 | saldanha
# Processing Record 23 of Set 5 | bathsheba
# Processing Record 24 of Set 5 | kamenka
# Processing Record 25 of Set 5 | mahebourg
# Processing Record 26 of Set 5 | oregon
# Processing Record 27 of Set 5 | pisco
# Processing Record 28 of Set 5 | kaitangata
# Processing Record 29 of Set 5 | boden
# Processing Record 30 of Set 5 | forrest city
# Processing Record 31 of Set 5 | nouadhibou
# Processing Record 32 of Set 5 | cap malheureux
# Processing Record 33 of Set 5 | los llanos de aridane
# Processing Record 34 of Set 5 | alta floresta
# Processing Record 35 of Set 5 | viet tri
# Processing Record 36 of Set 5 | omsukchan
# Processing Record 37 of Set 5 | saint-pierre
# Processing Record 38 of Set 5 | ucluelet
# Processing Record 39 of Set 5 | praia da vitoria
# Processing Record 40 of Set 5 | jagdalpur
# Processing Record 41 of Set 5 | mbandaka
# Processing Record 42 of Set 5 | kabinda
# Processing Record 43 of Set 5 | beloha
# Processing Record 44 of Set 5 | alice springs
# Processing Record 45 of Set 5 | ialibu
# Processing Record 46 of Set 5 | solwezi
# Processing Record 47 of Set 5 | sitka
# Processing Record 48 of Set 5 | andenes
# Processing Record 49 of Set 5 | zasechnoye
# Processing Record 50 of Set 5 | hofn
# Processing Record 1 of Set 6 | chokurdakh
# Processing Record 2 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 3 of Set 6 | isla mujeres
# Processing Record 4 of Set 6 | raigarh
# Processing Record 5 of Set 6 | igarka
# Processing Record 6 of Set 6 | taloda
# Processing Record 7 of Set 6 | komsomolskiy
# Processing Record 8 of Set 6 | uren
# Processing Record 9 of Set 6 | alice town
# Processing Record 10 of Set 6 | telfs
# Processing Record 11 of Set 6 | nalut
# Processing Record 12 of Set 6 | tingi
# Processing Record 13 of Set 6 | bagting
# Processing Record 14 of Set 6 | vao
# Processing Record 15 of Set 6 | saskylakh
# Processing Record 16 of Set 6 | hasaki
# Processing Record 17 of Set 6 | guane
# Processing Record 18 of Set 6 | iguape
# Processing Record 19 of Set 6 | vylkove
# Processing Record 20 of Set 6 | codrington
# Processing Record 21 of Set 6 | irituia
# Processing Record 22 of Set 6 | sao filipe
# Processing Record 23 of Set 6 | yarmouth
# Processing Record 24 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 25 of Set 6 | naze
# Processing Record 26 of Set 6 | manaure
# Processing Record 27 of Set 6 | emba
# Processing Record 28 of Set 6 | sambava
# Processing Record 29 of Set 6 | aramil
# Processing Record 30 of Set 6 | barra da estiva
# Processing Record 31 of Set 6 | lufilufi
# Processing Record 32 of Set 6 | yeletskiy
# City not found. Skipping...
# Processing Record 33 of Set 6 | derzhavinsk
# Processing Record 34 of Set 6 | georgetown
# Processing Record 35 of Set 6 | puri
# Processing Record 36 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 37 of Set 6 | clinton
# Processing Record 38 of Set 6 | teberda
# Processing Record 39 of Set 6 | narsaq
# Processing Record 40 of Set 6 | klyuchi
# Processing Record 41 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 43 of Set 6 | catamarca
# Processing Record 44 of Set 6 | lasa
# Processing Record 45 of Set 6 | astoria
# Processing Record 46 of Set 6 | carutapera
# Processing Record 47 of Set 6 | xichang
# Processing Record 48 of Set 6 | henties bay
# Processing Record 49 of Set 6 | banda aceh
# Processing Record 50 of Set 6 | asilah
# Processing Record 1 of Set 7 | irbeyskoye
# Processing Record 2 of Set 7 | pacific grove
# Processing Record 3 of Set 7 | pevek
# Processing Record 4 of Set 7 | borodino
# Processing Record 5 of Set 7 | luwuk
# Processing Record 6 of Set 7 | pacifica
# Processing Record 7 of Set 7 | gramada
# Processing Record 8 of Set 7 | sal rei
# Processing Record 9 of Set 7 | hvolsvollur
# Processing Record 10 of Set 7 | flinders
# Processing Record 11 of Set 7 | ulaanbaatar
# Processing Record 12 of Set 7 | skibbereen
# Processing Record 13 of Set 7 | fortuna
# Processing Record 14 of Set 7 | balabac
# Processing Record 15 of Set 7 | mahibadhoo
# Processing Record 16 of Set 7 | kabelvag
# Processing Record 17 of Set 7 | yarensk
# Processing Record 18 of Set 7 | alihe
# Processing Record 19 of Set 7 | newport
# Processing Record 20 of Set 7 | xiongzhou
# Processing Record 21 of Set 7 | seka
# Processing Record 22 of Set 7 | kedrovyy
# Processing Record 23 of Set 7 | gamba
# Processing Record 24 of Set 7 | khandyga
# Processing Record 25 of Set 7 | tres arroyos
# Processing Record 26 of Set 7 | djambala
# Processing Record 27 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 7 | cockburn town
# Processing Record 29 of Set 7 | coquimbo
# Processing Record 30 of Set 7 | kismayo
# Processing Record 31 of Set 7 | souillac
# Processing Record 32 of Set 7 | yeppoon
# Processing Record 33 of Set 7 | tessalit
# Processing Record 34 of Set 7 | tabou
# Processing Record 35 of Set 7 | magadan
# Processing Record 36 of Set 7 | biltine
# Processing Record 37 of Set 7 | wajima
# Processing Record 38 of Set 7 | mashpee
# Processing Record 39 of Set 7 | sisimiut
# Processing Record 40 of Set 7 | kruisfontein
# Processing Record 41 of Set 7 | vanimo
# Processing Record 42 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 7 | ostrovnoy
# Processing Record 44 of Set 7 | den helder
# Processing Record 45 of Set 7 | umm lajj
# Processing Record 46 of Set 7 | catuday
# Processing Record 47 of Set 7 | isangel
# Processing Record 48 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 8 | port hedland
# Processing Record 2 of Set 8 | guangyuan
# Processing Record 3 of Set 8 | ferme-neuve
# Processing Record 4 of Set 8 | florianopolis
# Processing Record 5 of Set 8 | taltal
# Processing Record 6 of Set 8 | morondava
# Processing Record 7 of Set 8 | ikongo
# Processing Record 8 of Set 8 | tomatlan
# Processing Record 9 of Set 8 | kiama
# Processing Record 10 of Set 8 | dunedin
# Processing Record 11 of Set 8 | mancio lima
# Processing Record 12 of Set 8 | champerico
# Processing Record 13 of Set 8 | okhotsk
# Processing Record 14 of Set 8 | kieta
# Processing Record 15 of Set 8 | kupang
# Processing Record 16 of Set 8 | carnduff
# Processing Record 17 of Set 8 | buin
# Processing Record 18 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 8 | bambanglipuro
# Processing Record 20 of Set 8 | la rioja
# Processing Record 21 of Set 8 | bay roberts
# Processing Record 22 of Set 8 | madang
# Processing Record 23 of Set 8 | caravelas
# Processing Record 24 of Set 8 | la plata
# Processing Record 25 of Set 8 | yumen
# Processing Record 26 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 8 | ouallam
# Processing Record 28 of Set 8 | higuey
# City not found. Skipping...
# Processing Record 29 of Set 8 | sarkand
# Processing Record 30 of Set 8 | kokopo
# Processing Record 31 of Set 8 | leduc
# Processing Record 32 of Set 8 | airai
# Processing Record 33 of Set 8 | kampot
# Processing Record 34 of Set 8 | san quintin
# Processing Record 35 of Set 8 | coihaique
# Processing Record 36 of Set 8 | port blair
# Processing Record 37 of Set 8 | kaka
# Processing Record 38 of Set 8 | goderich
# Processing Record 39 of Set 8 | mecca
# Processing Record 40 of Set 8 | ghanzi
# Processing Record 41 of Set 8 | deputatskiy
# Processing Record 42 of Set 8 | sol-iletsk
# Processing Record 43 of Set 8 | yuanping
# Processing Record 44 of Set 8 | amapa
# Processing Record 45 of Set 8 | dzhebariki-khaya
# Processing Record 46 of Set 8 | great bend
# Processing Record 47 of Set 8 | jubayl
# City not found. Skipping...
# Processing Record 48 of Set 8 | saint-leu
# Processing Record 49 of Set 8 | olkhovka
# Processing Record 50 of Set 8 | natal
# Processing Record 1 of Set 9 | guerrero negro
# Processing Record 2 of Set 9 | turukhansk
# Processing Record 3 of Set 9 | bardsir
# Processing Record 4 of Set 9 | saint albans
# Processing Record 5 of Set 9 | boueni
# Processing Record 6 of Set 9 | cairns
# Processing Record 7 of Set 9 | honiara
# Processing Record 8 of Set 9 | hay river
# Processing Record 9 of Set 9 | alibag
# Processing Record 10 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 11 of Set 9 | camapua
# Processing Record 12 of Set 9 | poltar
# Processing Record 13 of Set 9 | dhoraji
# Processing Record 14 of Set 9 | progreso
# Processing Record 15 of Set 9 | najran
# Processing Record 16 of Set 9 | ewa beach
# Processing Record 17 of Set 9 | hastings
# Processing Record 18 of Set 9 | beira
# Processing Record 19 of Set 9 | ukiah
# Processing Record 20 of Set 9 | cabedelo
# Processing Record 21 of Set 9 | lorengau
# Processing Record 22 of Set 9 | ginir
# Processing Record 23 of Set 9 | las vegas
# Processing Record 24 of Set 9 | huilong
# Processing Record 25 of Set 9 | bandarbeyla
# Processing Record 26 of Set 9 | otradnoye
# Processing Record 27 of Set 9 | port keats
# Processing Record 28 of Set 9 | port-gentil
# Processing Record 29 of Set 9 | coahuayana
# Processing Record 30 of Set 9 | bulalacao
# Processing Record 31 of Set 9 | paamiut
# Processing Record 32 of Set 9 | cedar city
# Processing Record 33 of Set 9 | businga
# Processing Record 34 of Set 9 | thana
# Processing Record 35 of Set 9 | naron
# Processing Record 36 of Set 9 | labuhan
# Processing Record 37 of Set 9 | simian
# Processing Record 38 of Set 9 | wanaka
# Processing Record 39 of Set 9 | kargala
# Processing Record 40 of Set 9 | spinus
# Processing Record 41 of Set 9 | launceston
# Processing Record 42 of Set 9 | loandjili
# Processing Record 43 of Set 9 | burgeo
# Processing Record 44 of Set 9 | nome
# Processing Record 45 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 46 of Set 9 | dingle
# Processing Record 47 of Set 9 | port augusta
# Processing Record 48 of Set 9 | ust-tsilma
# Processing Record 49 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 9 | quimper
# Processing Record 1 of Set 10 | sladkovo
# Processing Record 2 of Set 10 | owando
# Processing Record 3 of Set 10 | pecica
# Processing Record 4 of Set 10 | agadez
# Processing Record 5 of Set 10 | poronaysk
# Processing Record 6 of Set 10 | doka
# Processing Record 7 of Set 10 | aitape
# Processing Record 8 of Set 10 | akniste
# Processing Record 9 of Set 10 | amga
# Processing Record 10 of Set 10 | kagadi
# Processing Record 11 of Set 10 | zhob
# Processing Record 12 of Set 10 | eyl
# Processing Record 13 of Set 10 | tunduru
# City not found. Skipping...
# Processing Record 14 of Set 10 | leh
# Processing Record 15 of Set 10 | ambilobe
# Processing Record 16 of Set 10 | kurmanayevka
# Processing Record 17 of Set 10 | tukrah
# Processing Record 18 of Set 10 | partizansk
# Processing Record 19 of Set 10 | saint-felicien
# Processing Record 20 of Set 10 | mangochi
# Processing Record 21 of Set 10 | neiafu
# Processing Record 22 of Set 10 | auki
# Processing Record 23 of Set 10 | borogontsy
# Processing Record 24 of Set 10 | lagoa
# Processing Record 25 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 10 | mango
# Processing Record 27 of Set 10 | zhanaozen
# Processing Record 28 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 29 of Set 10 | ventspils
# Processing Record 30 of Set 10 | boa vista
# Processing Record 31 of Set 10 | barentu
# Processing Record 32 of Set 10 | andros town
# Processing Record 33 of Set 10 | broome
# Processing Record 34 of Set 10 | bermejo
# Processing Record 35 of Set 10 | zemio
# Processing Record 36 of Set 10 | nuevo ideal
# Processing Record 37 of Set 10 | ewo
# Processing Record 38 of Set 10 | roebourne
# Processing Record 39 of Set 10 | polyarnyy
# Processing Record 40 of Set 10 | mount isa
# Processing Record 41 of Set 10 | acapulco
# Processing Record 42 of Set 10 | cururupu
# Processing Record 43 of Set 10 | ballstad
# City not found. Skipping...
# Processing Record 44 of Set 10 | roma
# Processing Record 45 of Set 10 | novikovo
# Processing Record 46 of Set 10 | gallup
# Processing Record 47 of Set 10 | bowen
# Processing Record 48 of Set 10 | kondinskoye
# Processing Record 49 of Set 10 | megion
# Processing Record 50 of Set 10 | sotouboua
# Processing Record 1 of Set 11 | ust-maya
# Processing Record 2 of Set 11 | kanigiri
# Processing Record 3 of Set 11 | qaqortoq
# Processing Record 4 of Set 11 | dali
# Processing Record 5 of Set 11 | tatawin
# Processing Record 6 of Set 11 | powell river
# Processing Record 7 of Set 11 | saint-augustin
# Processing Record 8 of Set 11 | batemans bay
# Processing Record 9 of Set 11 | arica
# Processing Record 10 of Set 11 | santa rosa
# Processing Record 11 of Set 11 | khani
# Processing Record 12 of Set 11 | aklavik
# Processing Record 13 of Set 11 | vila franca do campo
# Processing Record 14 of Set 11 | linares
# Processing Record 15 of Set 11 | havre-saint-pierre
# Processing Record 16 of Set 11 | boende
# Processing Record 17 of Set 11 | meybod
# Processing Record 18 of Set 11 | dhidhdhoo
# Processing Record 19 of Set 11 | marzuq
# Processing Record 20 of Set 11 | araouane
# Processing Record 21 of Set 11 | wanning
# Processing Record 22 of Set 11 | maihar
# Processing Record 23 of Set 11 | axim
# Processing Record 24 of Set 11 | severo-kurilsk
# Processing Record 25 of Set 11 | santiago
# Processing Record 26 of Set 11 | santiago del estero
# Processing Record 27 of Set 11 | kysyl-syr
# Processing Record 28 of Set 11 | bath
# Processing Record 29 of Set 11 | choya
# Processing Record 30 of Set 11 | beberibe
# Processing Record 31 of Set 11 | ust-ishim
# Processing Record 32 of Set 11 | pinotepa nacional
# Processing Record 33 of Set 11 | port macquarie
# Processing Record 34 of Set 11 | twentynine palms
# Processing Record 35 of Set 11 | christchurch
# Processing Record 36 of Set 11 | vikulovo
# Processing Record 37 of Set 11 | ler
# Processing Record 38 of Set 11 | north bend
# Processing Record 39 of Set 11 | dakar
# Processing Record 40 of Set 11 | belmonte
# Processing Record 41 of Set 11 | brownsville
# Processing Record 42 of Set 11 | yomitan
# City not found. Skipping...
# Processing Record 43 of Set 11 | tawau
# Processing Record 44 of Set 11 | matamoros
# Processing Record 45 of Set 11 | byron bay
# Processing Record 46 of Set 11 | constitucion
# Processing Record 47 of Set 11 | itoman
# Processing Record 48 of Set 11 | kalabo
# Processing Record 49 of Set 11 | rosarito
# Processing Record 50 of Set 11 | sur
# Processing Record 1 of Set 12 | hervey bay
# Processing Record 2 of Set 12 | albina
# Processing Record 3 of Set 12 | dieppe
# Processing Record 4 of Set 12 | ishigaki
# Processing Record 5 of Set 12 | menongue
# Processing Record 6 of Set 12 | ondorhaan
# City not found. Skipping...
# Processing Record 7 of Set 12 | sheboygan
# Processing Record 8 of Set 12 | taburi
# City not found. Skipping...
# Processing Record 9 of Set 12 | creel
# Processing Record 10 of Set 12 | vila velha
# Processing Record 11 of Set 12 | eilenburg
# Processing Record 12 of Set 12 | saint-joseph
# Processing Record 13 of Set 12 | lingao
# Processing Record 14 of Set 12 | susanville
# Processing Record 15 of Set 12 | stokmarknes
# Processing Record 16 of Set 12 | tierralta
# Processing Record 17 of Set 12 | bosaso
# Processing Record 18 of Set 12 | xam nua
# Processing Record 19 of Set 12 | san jose
# Processing Record 20 of Set 12 | sadowara
# City not found. Skipping...
# Processing Record 21 of Set 12 | burnie
# Processing Record 22 of Set 12 | bubaque
# Processing Record 23 of Set 12 | pangnirtung
# Processing Record 24 of Set 12 | wilkes-barre
# Processing Record 25 of Set 12 | senneterre
# Processing Record 26 of Set 12 | petauke
# Processing Record 27 of Set 12 | namibe
# Processing Record 28 of Set 12 | shahpur
# Processing Record 29 of Set 12 | mana
# Processing Record 30 of Set 12 | korla
# Processing Record 31 of Set 12 | vitim
# Processing Record 32 of Set 12 | mocuba
# Processing Record 33 of Set 12 | huari
# Processing Record 34 of Set 12 | krasnoselkup
# Processing Record 35 of Set 12 | kazanskaya
# Processing Record 36 of Set 12 | sorland
# Processing Record 37 of Set 12 | umarkot
# Processing Record 38 of Set 12 | rakitovo
# Processing Record 39 of Set 12 | matara
# Processing Record 40 of Set 12 | bousso
# Processing Record 41 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 42 of Set 12 | omboue
# Processing Record 43 of Set 12 | rundu
# Processing Record 44 of Set 12 | vilcun
# Processing Record 45 of Set 12 | iqaluit
# Processing Record 46 of Set 12 | suntar
# Processing Record 47 of Set 12 | kalininsk
# Processing Record 48 of Set 12 | la union
# Processing Record 49 of Set 12 | ossora
# Processing Record 50 of Set 12 | nishihara
# Processing Record 1 of Set 13 | marsa matruh
# Processing Record 2 of Set 13 | matay
# Processing Record 3 of Set 13 | miyakonojo
# Processing Record 4 of Set 13 | kenai
# Processing Record 5 of Set 13 | otavi
# Processing Record 6 of Set 13 | fomboni
# Processing Record 7 of Set 13 | hobyo
# Processing Record 8 of Set 13 | pasighat
# Processing Record 9 of Set 13 | vanavara
# Processing Record 10 of Set 13 | marfino
# Processing Record 11 of Set 13 | prainha
# Processing Record 12 of Set 13 | sovetskiy
# Processing Record 13 of Set 13 | tukan
# Processing Record 14 of Set 13 | tambacounda
# Processing Record 15 of Set 13 | sibu
# Processing Record 16 of Set 13 | vostok
# Processing Record 17 of Set 13 | dolinsk
# Processing Record 18 of Set 13 | armidale
# Processing Record 19 of Set 13 | hamilton
# Processing Record 20 of Set 13 | kavaratti
# Processing Record 21 of Set 13 | haines junction
# Processing Record 22 of Set 13 | silifke
# Processing Record 23 of Set 13 | leningradskiy
# Processing Record 24 of Set 13 | morgan city
# Processing Record 25 of Set 13 | granard
# Processing Record 26 of Set 13 | san vicente
# Processing Record 27 of Set 13 | preobrazheniye
# Processing Record 28 of Set 13 | maku
# Processing Record 29 of Set 13 | linkou
# Processing Record 30 of Set 13 | thinadhoo
# Processing Record 31 of Set 13 | tadine
# Processing Record 32 of Set 13 | rassvet
# Processing Record 33 of Set 13 | pedernales
# Processing Record 34 of Set 13 | san juan
# Processing Record 35 of Set 13 | ziro
# Processing Record 36 of Set 13 | muros
# Processing Record 37 of Set 13 | san-pedro
# Processing Record 38 of Set 13 | tancheng
# Processing Record 39 of Set 13 | joue-les-tours
# Processing Record 40 of Set 13 | newton
# Processing Record 41 of Set 13 | panama city
# Processing Record 42 of Set 13 | reconquista
# Processing Record 43 of Set 13 | chapais
# Processing Record 44 of Set 13 | sault sainte marie
# Processing Record 45 of Set 13 | bethanien
# Processing Record 46 of Set 13 | severnoye
# Processing Record 47 of Set 13 | dekoa
# City not found. Skipping...
# Processing Record 48 of Set 13 | winslow
# Processing Record 49 of Set 13 | dzilam gonzalez
# Processing Record 50 of Set 13 | loiza
# Processing Record 1 of Set 14 | laishevo
# Processing Record 2 of Set 14 | trelew
# Processing Record 3 of Set 14 | clarence town
# Processing Record 4 of Set 14 | krasnosilka
# Processing Record 5 of Set 14 | afonso bezerra
# Processing Record 6 of Set 14 | huarmey
# Processing Record 7 of Set 14 | buritis
# Processing Record 8 of Set 14 | shu
# Processing Record 9 of Set 14 | mildura
# Processing Record 10 of Set 14 | opportunity
# Processing Record 11 of Set 14 | asahikawa
# Processing Record 12 of Set 14 | coetupo
# City not found. Skipping...
# Processing Record 13 of Set 14 | tornio
# Processing Record 14 of Set 14 | carauari
# Processing Record 15 of Set 14 | bac lieu
# Processing Record 16 of Set 14 | gopalpur
# Processing Record 17 of Set 14 | fonte boa
# Processing Record 18 of Set 14 | murdochville
# Processing Record 19 of Set 14 | shibarghan
# City not found. Skipping...
# Processing Record 20 of Set 14 | rantepao
# Processing Record 21 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 14 | haapu
# City not found. Skipping...
# Processing Record 23 of Set 14 | fort nelson
# Processing Record 24 of Set 14 | tamandare
# Processing Record 25 of Set 14 | sao luis de montes belos
# Processing Record 26 of Set 14 | marion
# Processing Record 27 of Set 14 | stavanger
# Processing Record 28 of Set 14 | blois
# Processing Record 29 of Set 14 | itarema
# Processing Record 30 of Set 14 | pousat
# City not found. Skipping...
# Processing Record 31 of Set 14 | lavrentiya
# Processing Record 32 of Set 14 | loveland
# Processing Record 33 of Set 14 | concordia
# Processing Record 34 of Set 14 | novo aripuana
# Processing Record 35 of Set 14 | masvingo
# Processing Record 36 of Set 14 | gao
# Processing Record 37 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 38 of Set 14 | kongoussi
# Processing Record 39 of Set 14 | nyurba
# Processing Record 40 of Set 14 | san matias
# Processing Record 41 of Set 14 | denpasar
# Processing Record 42 of Set 14 | tura
# Processing Record 43 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 14 | charters towers
# Processing Record 45 of Set 14 | slobidka
# Processing Record 46 of Set 14 | dunhua
# Processing Record 47 of Set 14 | svobodnyy
# Processing Record 48 of Set 14 | alofi
# Processing Record 49 of Set 14 | inongo
# Processing Record 50 of Set 14 | erzin
# Processing Record 1 of Set 15 | manokwari
# Processing Record 2 of Set 15 | cortes
# Processing Record 3 of Set 15 | margate
# Processing Record 4 of Set 15 | oktyabrskiy
# Processing Record 5 of Set 15 | san jeronimo
# Processing Record 6 of Set 15 | hashtrud
# Processing Record 7 of Set 15 | solosolo
# Processing Record 8 of Set 15 | empalme
# Processing Record 9 of Set 15 | tombouctou
# Processing Record 10 of Set 15 | kiunga
# Processing Record 11 of Set 15 | price
# Processing Record 12 of Set 15 | mizdah
# Processing Record 13 of Set 15 | baiyin
# Processing Record 14 of Set 15 | aksu
# Processing Record 15 of Set 15 | caucaia
# Processing Record 16 of Set 15 | almaznyy
# Processing Record 17 of Set 15 | alenquer
# Processing Record 18 of Set 15 | yankton
# Processing Record 19 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 20 of Set 15 | sudak
# Processing Record 21 of Set 15 | mersing
# Processing Record 22 of Set 15 | ionia
# Processing Record 23 of Set 15 | glomfjord
# Processing Record 24 of Set 15 | beyneu
# Processing Record 25 of Set 15 | jalu
# Processing Record 26 of Set 15 | skiros
# City not found. Skipping...
# Processing Record 27 of Set 15 | nerekhta
# Processing Record 28 of Set 15 | roald
# Processing Record 29 of Set 15 | rimouski
# Processing Record 30 of Set 15 | waipawa
# Processing Record 31 of Set 15 | sawakin
# Processing Record 32 of Set 15 | sundumbili
# Processing Record 33 of Set 15 | half moon bay
# Processing Record 34 of Set 15 | chumikan
# Processing Record 35 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 15 | pozoblanco
# Processing Record 37 of Set 15 | camacha
# Processing Record 38 of Set 15 | saint-francois
# Processing Record 39 of Set 15 | ailigandi
# Processing Record 40 of Set 15 | vila
# Processing Record 41 of Set 15 | gat
# Processing Record 42 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 15 | yanam
# Processing Record 44 of Set 15 | kalmunai
# Processing Record 45 of Set 15 | moncagua
# Processing Record 46 of Set 15 | hualmay
# Processing Record 47 of Set 15 | porterville
# Processing Record 48 of Set 15 | windsor
# Processing Record 49 of Set 15 | sibolga
# Processing Record 50 of Set 15 | severnyy
# Processing Record 1 of Set 16 | lins
# Processing Record 2 of Set 16 | kyra
# Processing Record 3 of Set 16 | ofunato
# Processing Record 4 of Set 16 | xirokambion
# City not found. Skipping...
# Processing Record 5 of Set 16 | ardistan
# City not found. Skipping...
# Processing Record 6 of Set 16 | leshukonskoye
# Processing Record 7 of Set 16 | bloomingdale
# Processing Record 8 of Set 16 | bira
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Cidreira      BR -30.1811  -50.2056     64.69        72         100
# 1  Saint George      US  37.1041 -113.5841     74.62        14           0
# 2     Kisangani      CD   0.5167   25.2000     69.53        99         100
# 3     Jamestown      US  42.0970  -79.2353     55.02        93         100
# 4      Khatanga      RU  71.9667  102.5000     18.16        86          97
# 5    Port Hardy      CA  50.6996 -127.4199     53.78        62         100
# 6      Victoria      HK  22.2855  114.1577     63.25        92         100
# 7       Mataura      NZ -46.1927  168.8643     63.48        55          26
# 8       Rikitea      PF -23.1203 -134.9692     76.59        70         100
# 9        Nemuro      JP  43.3236  145.5750     41.05        96         100
#
#    Wind Speed Current Description
# 0        6.64     overcast clouds
# 1       27.63           clear sky
# 2        2.04     overcast clouds
# 3       13.80     overcast clouds
# 4       11.65     overcast clouds
# 5        2.30     overcast clouds
# 6        5.99          light rain
# 7        5.37    scattered clouds
# 8        6.20     overcast clouds
# 9       28.83          light rain

# %%
city_data_df.to_csv("WeatherPy_Database.csv")
